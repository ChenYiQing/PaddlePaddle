# %% [markdown]
# ### 目标
# * 通过代码生成训练的图片和标签
# * 将自己的训练集合喂给PaddlePaddle

# %%
import numpy
numpy.random.random(size=(1,13)).astype('float32')
#numpy.random.random(size=(1,1)).astype('float32')
#print(a)
#print(b)
# Out:
# array([[0.33599833, 0.794628  , 0.608309  , 0.44820383, 0.53892773,
#         0.84507966, 0.23914316, 0.88451535, 0.30529317, 0.50806755,
#         0.5699564 , 0.7011518 , 0.5306415 ]], dtype=float32)

# %% [markdown]
# ## numpy知识准备

# %%
import numpy as np
numpy.array([[1.1,2.2,3.3]],dtype='float32')

#a = 4
#b = [[a]]

aa=np.empty([0,13],'float32')
bb = [1.1,2.2,3.2,4.3,5,6,7,8,9,10,11,12,13]
cc=[bb] 
aa = np.append(aa, cc,axis=0)
print(aa)
# Out:
# [[ 1.1  2.2  3.2  4.3  5.   6.   7.   8.   9.  10.  11.  12.  13. ]]

# %% [markdown]
# ## PaddlePadlle

# %%
import paddle
import paddle.fluid as fluid
import numpy
import math
import sys


# For training test cost
def train_test(executor, program, reader, feeder, fetch_list):
    accumulated = 1 * [0]
    count = 0
    for data_test in reader():
        outs = executor.run(
            program=program, feed=feeder.feed(data_test), fetch_list=fetch_list)
        accumulated = [x_c[0] + x_c[1][0] for x_c in zip(accumulated, outs)]
        count += 1
    return [x_d / count for x_d in accumulated]


def main():
    batch_size = 20
    train_reader = paddle.batch(
        paddle.reader.shuffle(paddle.dataset.uci_housing.train(), buf_size=500),
        batch_size=batch_size)
    test_reader = paddle.batch(
        paddle.reader.shuffle(paddle.dataset.uci_housing.test(), buf_size=500),
        batch_size=batch_size)

    # feature vector of length 13
    x = fluid.layers.data(name='x', shape=[13], dtype='float32')
    y = fluid.layers.data(name='y', shape=[1], dtype='float32')
    y_predict = fluid.layers.fc(input=x, size=1, act=None)

    main_program = fluid.default_main_program()
    startup_program = fluid.default_startup_program()

    cost = fluid.layers.square_error_cost(input=y_predict, label=y)
    avg_loss = fluid.layers.mean(cost)

    sgd_optimizer = fluid.optimizer.SGD(learning_rate=0.001)
    sgd_optimizer.minimize(avg_loss)

    test_program = main_program.clone(for_test=True)

    # can use CPU or GPU
    use_cuda = True
    place = fluid.CUDAPlace(0) if use_cuda else fluid.CPUPlace()
    exe = fluid.Executor(place)

    # Specify the directory to save the parameters
    params_dirname = "fit_a_line.inference.model"
    num_epochs = 100

    # main train loop.
    feeder = fluid.DataFeeder(place=place, feed_list=[x, y])
    exe.run(startup_program)

    train_prompt = "Train cost"
    test_prompt = "Test cost"
    step = 0

    exe_test = fluid.Executor(place)

    aa=numpy.empty([0,13],'float32')
    bb = [1.1,2.2,3.2,4.3,5,6,7,8,9,10,11,12,13]
    cc=[bb] 
    aa = numpy.append(aa, cc,axis=0)
    
    for pass_id in range(num_epochs):
        for data_train in train_reader():
#            avg_loss_value, = exe.run(
#                main_program,
#                feed=feeder.feed(data_train),
#                fetch_list=[avg_loss])
            avg_loss_value, = exe.run(
                main_program,
                feed={
                       "x": aa.astype('float32'),
                       "y": numpy.random.random(size=(1,1)).astype('float32')
                },
                fetch_list=[avg_loss])
            step += 1
            if step % 10 == 0:  # record a train cost every 10 batches
                print("%s, Step %d, Cost %f" %
                      (train_prompt, step, avg_loss_value[0]))

#            if step % 100 == 0:  # record a test cost every 100 batches
#                test_metics = train_test(
#                    executor=exe_test,
#                    program=test_program,
#                    reader=test_reader,
#                    fetch_list=[avg_loss],
#                    feeder=feeder)
#                print("%s, Step %d, Cost %f" %
#                      (test_prompt, step, test_metics[0]))
                # If the accuracy is good enough, we can stop the training.
#                if test_metics[0] < 10.0:
#                    break

            

            if math.isnan(float(avg_loss_value[0])):
                sys.exit("got NaN loss, training failed.")
        if params_dirname is not None:
            # We can save the trained parameters for the inferences later
            fluid.io.save_inference_model(params_dirname, ['x'], [y_predict],
                                          exe)

    infer_exe = fluid.Executor(place)
    inference_scope = fluid.core.Scope()

    # infer
    '''
    with fluid.scope_guard(inference_scope):
        [inference_program, feed_target_names, fetch_targets
         ] = fluid.io.load_inference_model(params_dirname, infer_exe)
        batch_size = 10

        infer_reader = paddle.batch(
            paddle.dataset.uci_housing.test(), batch_size=batch_size)

        infer_data = next(infer_reader())
        infer_feat = numpy.array(
            [data[0] for data in infer_data]).astype("float32")
        infer_label = numpy.array(
            [data[1] for data in infer_data]).astype("float32")

        assert feed_target_names[0] == 'x'
        results = infer_exe.run(
            inference_program,
            feed={feed_target_names[0]: numpy.array(infer_feat)},
            fetch_list=fetch_targets)

        print("infer results: (House Price)")
        for idx, val in enumerate(results[0]):
            print("%d: %.2f" % (idx, val))

        print("\nground truth:")
        for idx, val in enumerate(infer_label):
            print("%d: %.2f" % (idx, val))
    '''

if __name__ == '__main__':
    main()
# Out:
# Train cost, Step 10, Cost 0.059951
# Train cost, Step 20, Cost 0.129301
# Train cost, Step 30, Cost 0.005047
# Train cost, Step 40, Cost 1.033324
# Train cost, Step 50, Cost 0.827357
# Train cost, Step 60, Cost 0.015599
# Train cost, Step 70, Cost 0.029490
# Train cost, Step 80, Cost 0.004426
# Train cost, Step 90, Cost 0.049888
# Train cost, Step 100, Cost 0.297915
# Train cost, Step 110, Cost 0.005839
# Train cost, Step 120, Cost 2.469226
# Train cost, Step 130, Cost 0.072924
# Train cost, Step 140, Cost 0.586453
# Train cost, Step 150, Cost 0.121222
# Train cost, Step 160, Cost 1.974009
# Train cost, Step 170, Cost 1.694570
# Train cost, Step 180, Cost 0.057092
# Train cost, Step 190, Cost 0.073002
# Train cost, Step 200, Cost 0.213113
# Train cost, Step 210, Cost 1.201815
# Train cost, Step 220, Cost 0.241088
# Train cost, Step 230, Cost 3.496897
# Train cost, Step 240, Cost 0.048167
# Train cost, Step 250, Cost 0.082243
# Train cost, Step 260, Cost 0.035305
# Train cost, Step 270, Cost 0.830913
# Train cost, Step 280, Cost 0.009463
# Train cost, Step 290, Cost 0.082161
# Train cost, Step 300, Cost 0.251474
# Train cost, Step 310, Cost 0.021790
# Train cost, Step 320, Cost 0.007204
# Train cost, Step 330, Cost 0.055174
# Train cost, Step 340, Cost 0.026972
# Train cost, Step 350, Cost 0.149004
# Train cost, Step 360, Cost 0.470922
# Train cost, Step 370, Cost 0.066487
# Train cost, Step 380, Cost 1.034173
# Train cost, Step 390, Cost 0.433775
# Train cost, Step 400, Cost 0.109567
# Train cost, Step 410, Cost 0.474668
# Train cost, Step 420, Cost 0.014098
# Train cost, Step 430, Cost 0.020294
# Train cost, Step 440, Cost 0.765050
# Train cost, Step 450, Cost 0.576875
# Train cost, Step 460, Cost 0.135608
# Train cost, Step 470, Cost 0.273904
# Train cost, Step 480, Cost 0.146062
# Train cost, Step 490, Cost 0.758613
# Train cost, Step 500, Cost 0.324739
# Train cost, Step 510, Cost 0.086023
# Train cost, Step 520, Cost 1.067994
# Train cost, Step 530, Cost 0.798282
# Train cost, Step 540, Cost 2.262202
# Train cost, Step 550, Cost 0.168770
# Train cost, Step 560, Cost 0.958213
# Train cost, Step 570, Cost 0.056216
# Train cost, Step 580, Cost 0.476920
# Train cost, Step 590, Cost 0.994289
# Train cost, Step 600, Cost 0.024224
# Train cost, Step 610, Cost 0.378819
# Train cost, Step 620, Cost 0.765011
# Train cost, Step 630, Cost 0.018441
# Train cost, Step 640, Cost 0.158388
# Train cost, Step 650, Cost 0.002327
# Train cost, Step 660, Cost 0.153378
# Train cost, Step 670, Cost 1.360208
# Train cost, Step 680, Cost 3.361905
# Train cost, Step 690, Cost 2.009138
# Train cost, Step 700, Cost 0.351713
# Train cost, Step 710, Cost 2.037684
# Train cost, Step 720, Cost 0.108570
# Train cost, Step 730, Cost 1.232410
# Train cost, Step 740, Cost 0.772057
# Train cost, Step 750, Cost 1.656347
# Train cost, Step 760, Cost 0.057183
# Train cost, Step 770, Cost 0.266901
# Train cost, Step 780, Cost 0.409618
# Train cost, Step 790, Cost 0.008535
# Train cost, Step 800, Cost 2.410162
# Train cost, Step 810, Cost 1.165496
# Train cost, Step 820, Cost 0.000016
# Train cost, Step 830, Cost 0.005898
# Train cost, Step 840, Cost 0.914206
# Train cost, Step 850, Cost 0.025165
# Train cost, Step 860, Cost 0.110992
# Train cost, Step 870, Cost 0.033120
# Train cost, Step 880, Cost 1.242812
# Train cost, Step 890, Cost 0.022610
# Train cost, Step 900, Cost 0.002209
# Train cost, Step 910, Cost 0.598993
# Train cost, Step 920, Cost 0.003015
# Train cost, Step 930, Cost 1.453387
# Train cost, Step 940, Cost 0.365696
# Train cost, Step 950, Cost 1.118775
# Train cost, Step 960, Cost 0.233380
# Train cost, Step 970, Cost 0.006805
# Train cost, Step 980, Cost 0.221039
# Train cost, Step 990, Cost 0.665250
# Train cost, Step 1000, Cost 0.792702
# Train cost, Step 1010, Cost 1.107954
# Train cost, Step 1020, Cost 0.161835
# Train cost, Step 1030, Cost 0.113975
# Train cost, Step 1040, Cost 1.086207
# Train cost, Step 1050, Cost 0.102333
# Train cost, Step 1060, Cost 0.435389
# Train cost, Step 1070, Cost 0.266143
# Train cost, Step 1080, Cost 0.354964
# Train cost, Step 1090, Cost 0.062740
# Train cost, Step 1100, Cost 0.168769
# Train cost, Step 1110, Cost 0.801178
# Train cost, Step 1120, Cost 1.095810
# Train cost, Step 1130, Cost 0.007280
# Train cost, Step 1140, Cost 1.421519
# Train cost, Step 1150, Cost 1.415940
# Train cost, Step 1160, Cost 0.171619
# Train cost, Step 1170, Cost 0.008733
# Train cost, Step 1180, Cost 1.478984
# Train cost, Step 1190, Cost 0.837876
# Train cost, Step 1200, Cost 2.147696
# Train cost, Step 1210, Cost 0.346344
# Train cost, Step 1220, Cost 0.007937
# Train cost, Step 1230, Cost 0.559306
# Train cost, Step 1240, Cost 1.431110
# Train cost, Step 1250, Cost 0.397048
# Train cost, Step 1260, Cost 0.044663
# Train cost, Step 1270, Cost 0.583525
# Train cost, Step 1280, Cost 0.029849
# Train cost, Step 1290, Cost 0.000110
# Train cost, Step 1300, Cost 1.044685
# Train cost, Step 1310, Cost 0.050841
# Train cost, Step 1320, Cost 0.001340
# Train cost, Step 1330, Cost 1.100617
# Train cost, Step 1340, Cost 0.612354
# Train cost, Step 1350, Cost 0.165798
# Train cost, Step 1360, Cost 0.255905
# Train cost, Step 1370, Cost 0.894684
# Train cost, Step 1380, Cost 0.922146
# Train cost, Step 1390, Cost 0.338343
# Train cost, Step 1400, Cost 0.006494
# Train cost, Step 1410, Cost 0.810855
# Train cost, Step 1420, Cost 0.628575
# Train cost, Step 1430, Cost 0.006068
# Train cost, Step 1440, Cost 0.558491
# Train cost, Step 1450, Cost 0.061809
# Train cost, Step 1460, Cost 0.174443
# Train cost, Step 1470, Cost 0.703775
# Train cost, Step 1480, Cost 0.379299
# Train cost, Step 1490, Cost 0.953463
# Train cost, Step 1500, Cost 3.018750
# Train cost, Step 1510, Cost 2.946560
# Train cost, Step 1520, Cost 0.070495
# Train cost, Step 1530, Cost 0.632612
# Train cost, Step 1540, Cost 0.067527
# Train cost, Step 1550, Cost 0.011650
# Train cost, Step 1560, Cost 0.080546
# Train cost, Step 1570, Cost 0.023679
# Train cost, Step 1580, Cost 0.139234
# Train cost, Step 1590, Cost 0.847971
# Train cost, Step 1600, Cost 2.529758
# Train cost, Step 1610, Cost 0.000307
# Train cost, Step 1620, Cost 0.006015
# Train cost, Step 1630, Cost 0.774749
# Train cost, Step 1640, Cost 0.219162
# Train cost, Step 1650, Cost 0.078158
# Train cost, Step 1660, Cost 0.449115
# Train cost, Step 1670, Cost 0.404366
# Train cost, Step 1680, Cost 0.025721
# Train cost, Step 1690, Cost 0.659990
# Train cost, Step 1700, Cost 0.148851
# Train cost, Step 1710, Cost 0.661002
# Train cost, Step 1720, Cost 0.043460
# Train cost, Step 1730, Cost 0.184074
# Train cost, Step 1740, Cost 0.188010
# Train cost, Step 1750, Cost 0.000523
# Train cost, Step 1760, Cost 1.498904
# Train cost, Step 1770, Cost 0.417307
# Train cost, Step 1780, Cost 0.332107
# Train cost, Step 1790, Cost 0.001507
# Train cost, Step 1800, Cost 1.070822
# Train cost, Step 1810, Cost 0.349529
# Train cost, Step 1820, Cost 0.097800
# Train cost, Step 1830, Cost 0.033817
# Train cost, Step 1840, Cost 0.385184
# Train cost, Step 1850, Cost 0.061084
# Train cost, Step 1860, Cost 0.047366
# Train cost, Step 1870, Cost 0.118349
# Train cost, Step 1880, Cost 0.037680
# Train cost, Step 1890, Cost 1.432762
# Train cost, Step 1900, Cost 0.178394
# Train cost, Step 1910, Cost 0.187861
# Train cost, Step 1920, Cost 0.329000
# Train cost, Step 1930, Cost 0.697459
# Train cost, Step 1940, Cost 0.016714
# Train cost, Step 1950, Cost 0.448547
# Train cost, Step 1960, Cost 2.060492
# Train cost, Step 1970, Cost 0.284514
# Train cost, Step 1980, Cost 0.310255
# Train cost, Step 1990, Cost 0.113924
# Train cost, Step 2000, Cost 0.017934
# Train cost, Step 2010, Cost 0.038015
# Train cost, Step 2020, Cost 0.621053
# Train cost, Step 2030, Cost 0.093973
# Train cost, Step 2040, Cost 2.824642
# Train cost, Step 2050, Cost 0.490770
# Train cost, Step 2060, Cost 0.013504
# Train cost, Step 2070, Cost 0.127437
# Train cost, Step 2080, Cost 0.034847
# Train cost, Step 2090, Cost 0.086885
# Train cost, Step 2100, Cost 0.257838
